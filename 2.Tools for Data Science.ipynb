# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# P Dharithri Sravya
# Student

# %% [markdown]
# _I am intersted in Data Science beacause I am fascinated by the insights given by data.I am also interested in Maths_

# %% [markdown]
# ### Addition of 3 numbers

# %%
a=3
b=2
c=4
print(a+b+c)
# Out:
# 9

# %% [markdown]
# ***
# **This is ordered list**
# 1. Data Science
# 2. Coursera
# 3. Watson studio
# **This is link**
# [link for coursera](https://www.coursera.org/)
# **This is unordered list**
# <ul>
#     <li>Python</li>
#     <li>R</li>
#     <li>SQL</li>
# </ul>
#
# ***
